# %%
import pandas as pd

# %%
#df = pd.read_xml("Original Voyageur Alarms.xml")

# %%
import xmltodict

# %%
with open("Original Voyageur Alarms.xml", 'rt') as f:
    xml_orig = f.read()

# %%
my_dict = xmltodict.parse(xml_orig)

# %%
trg_list_orig = my_dict['alarms']['alarm']['triggers']['trigger']

# %%
msg_list_orig = my_dict['alarms']['alarm']['messages']['message']

# %%
exp_list = []
for i in range(len(trg_list_orig)):
    exp_list.append(trg_list_orig[i]['@exp'])

# %%
exp_list[:20]
# Out:
# ['{[OPRA]TAG_WORD_AT601A}',
#  '{[OPRA]TAG_WORD_FSL603}',
#  '{[OPRA]TAG_WORD_HS602}',
#  '{[OPRA]TAG_WORD_LSL335A}',
#  '{[OPRA]TAG_WORD_LSL335B}',
#  '{[OPRA]TAG_WORD_PDSH338}',
#  '{[OPRA]TAG_WORD_PDSH332}',
#  '{[OPRA]TAG_WORD_PDSH367}',
#  '{[OPRA]TAG_WORD_PDSH388}',
#  '{[OPRA]TAG_WORD_PdT614}',
#  '{[OPRA]TAG_WORD_PdT606}',
#  '{[OPRA]TAG_WORD_PdT607}',
#  '{[OPRA]TAG_WORD_PdY364}',
#  '{[OPRA]TAG_WORD_PT110}',
#  '{[OPRA]TAG_WORD_PT160}',
#  '{[OPRA]TAG_WORD_PT231}',
#  '{[OPRA]TAG_WORD_PT240}',
#  '{[OPRA]TAG_WORD_PT341}',
#  '{[OPRA]TAG_WORD_PT360}',
#  '{[OPRA]TAG_WORD_PT364A}']

# %%
trg_list_orig[10]
# Out:
# {'@id': 'T11',
#  '@type': 'bit',
#  '@ack-all-value': '0',
#  '@use-ack-all': 'false',
#  '@ack-tag': '',
#  '@exp': '{[OPRA]TAG_WORD_PdT606}',
#  '@message-tag': '',
#  '@message-handshake-exp': '',
#  '@message-notification-tag': '',
#  '@remote-ack-exp': '',
#  '@remote-ack-handshake-tag': '',
#  '@label': 'PdT606',
#  '@handshake-tag': ''}

# %%
msg_list_orig[10]
# Out:
# {'@id': 'M11',
#  '@trigger-value': '2',
#  '@identifier': '0',
#  '@trigger': '#T94',
#  '@backcolor': '#FFFF00',
#  '@forecolor': '#000000',
#  '@audio': 'false',
#  '@display': 'true',
#  '@print': 'false',
#  '@message-to-tag': 'false',
#  '@text': 'AT601B Gas Detection Engine Room Ventilation Exit High Alarm'}

# %%
df_trg = pd.DataFrame(trg_list_orig)

# %%
col_list = df_trg.columns.to_list()

# %%
new_col_list = [s.replace('@', '') for s in col_list]
new_col_list
# Out:
# ['id',
#  'type',
#  'ack-all-value',
#  'use-ack-all',
#  'ack-tag',
#  'exp',
#  'message-tag',
#  'message-handshake-exp',
#  'message-notification-tag',
#  'remote-ack-exp',
#  'remote-ack-handshake-tag',
#  'label',
#  'handshake-tag']

# %%
df_trg.columns = new_col_list

# %%
df_trg
# Out:
#        id type ack-all-value use-ack-all ack-tag                        exp  \
# 0      T1  bit             0       false            {[OPRA]TAG_WORD_AT601A}
# 1      T2  bit             0       false            {[OPRA]TAG_WORD_FSL603}
# 2      T3  bit             0       false             {[OPRA]TAG_WORD_HS602}
# 3      T4  bit             0       false           {[OPRA]TAG_WORD_LSL335A}
# 4      T5  bit             0       false           {[OPRA]TAG_WORD_LSL335B}
# ..    ...  ...           ...         ...     ...                        ...
# 266  T267  bit             0       false          {[OPRA]TAG_WORD_STEP_363}
# 267  T268  bit             0       false          {[OPRA]TAG_WORD_STEP_364}
# 268  T269  bit             0       false          {[OPRA]TAG_WORD_STEP_365}
# 269  T270  bit             0       false             {[OPRA]TAG_WORD_XV375}
# 270  T271  bit             0       false             {[OPRA]TAG_WORD_XV376}
#
#     message-tag message-handshake-exp message-notification-tag remote-ack-exp  \
# 0
# 1
# 2
# 3
# 4
# ..          ...                   ...                      ...            ...
# 266
# 267
# 268
# 269
# 270
#
#     remote-ack-handshake-tag    label handshake-tag
# 0                              AT601A
# 1                              FSL603
# 2                               HS602
# 3                             LSL335A
# 4                             LSL335B
# ..                       ...      ...           ...
# 266                           Step363
# 267                           Step364
# 268                           Step365
# 269                             XV375
# 270                             XV376
#
# [271 rows x 13 columns]

# %%
df_msg = pd.DataFrame(msg_list_orig)
col_list = df_msg.columns.to_list()
new_col_list = [s.replace('@', '') for s in col_list]
df_msg.columns = new_col_list
df_msg
# Out:
#        id trigger-value identifier trigger backcolor forecolor  audio display  \
# 0      M1             2          0   #T160   #FFFF00   #000000  false    true
# 1      M2             3          0   #T160   #FFFF00   #000000  false    true
# 2      M3             4          0   #T160   #FFFF00   #000000  false    true
# 3      M4             5          0   #T160   #FFFF00   #000000  false    true
# 4      M5             6          0   #T160   #FFFF00   #000000  false    true
# ..    ...           ...        ...     ...       ...       ...    ...     ...
# 536  M537             6          0   #T266   #FF0000   #000000  false    true
# 537  M538             6          0   #T267   #FF0000   #000000  false    true
# 538  M539             6          0   #T268   #FF0000   #000000  false    true
# 539  M540             6          0   #T269   #FF0000   #000000  false    true
# 540  M541             4          0    #T47   #FFFF00   #000000  false    true
#
#      print message-to-tag                                               text
# 0    false          false                          Device Net Module 1 Fault
# 1    false          false                          Device Net Module 2 Fault
# 2    false          false                          Device Net Module 3 Fault
# 3    false          false                          Device Net Module 4 Fault
# 4    false          false                          Device Net Module 5 Fault
# ..     ...            ...                                                ...
# 536  false          false  Gas Fuel System Step 362 Timed Out (Gas Flush-...
# 537  false          false  Gas Fuel System Step 363 Timed Out (Gas Flush-...
# 538  false          false  Gas Fuel System Step 364 Timed Out (Stop Gas f...
# 539  false          false  Gas Fuel System Step 365 Timed Out (Close Gas ...
# 540  false          false         TE362 Gas Fuel Temperature Low low Alarm,
#
# [541 rows x 11 columns]

# %%
df_msg.trigger = df_msg.trigger.str.replace('#', '')
df_msg
# Out:
#        id trigger-value identifier trigger backcolor forecolor  audio display  \
# 0      M1             2          0    T160   #FFFF00   #000000  false    true
# 1      M2             3          0    T160   #FFFF00   #000000  false    true
# 2      M3             4          0    T160   #FFFF00   #000000  false    true
# 3      M4             5          0    T160   #FFFF00   #000000  false    true
# 4      M5             6          0    T160   #FFFF00   #000000  false    true
# ..    ...           ...        ...     ...       ...       ...    ...     ...
# 536  M537             6          0    T266   #FF0000   #000000  false    true
# 537  M538             6          0    T267   #FF0000   #000000  false    true
# 538  M539             6          0    T268   #FF0000   #000000  false    true
# 539  M540             6          0    T269   #FF0000   #000000  false    true
# 540  M541             4          0     T47   #FFFF00   #000000  false    true
#
#      print message-to-tag                                               text
# 0    false          false                          Device Net Module 1 Fault
# 1    false          false                          Device Net Module 2 Fault
# 2    false          false                          Device Net Module 3 Fault
# 3    false          false                          Device Net Module 4 Fault
# 4    false          false                          Device Net Module 5 Fault
# ..     ...            ...                                                ...
# 536  false          false  Gas Fuel System Step 362 Timed Out (Gas Flush-...
# 537  false          false  Gas Fuel System Step 363 Timed Out (Gas Flush-...
# 538  false          false  Gas Fuel System Step 364 Timed Out (Stop Gas f...
# 539  false          false  Gas Fuel System Step 365 Timed Out (Close Gas ...
# 540  false          false         TE362 Gas Fuel Temperature Low low Alarm,
#
# [541 rows x 11 columns]

# %%
df = pd.merge(df_trg, df_msg, left_on='id', right_on='trigger')

# %%
def add_type(row):

    match row['trigger-value']:
        case '1': return 'HighHigh'
        case '2': return 'High'
        case '3': return 'Low'
        case '4': return 'LowLow'
        case '5': return 'Sensor Defect'
        case '6': return 'High Switch Alarm'
        case other: return 'EXCEPTION'

def add_trip(row):
    match row['trigger-value']:
        case '1': return 'TRIP'
        case '2': return 'HI'
        case '3': return 'LO'
        case '4': return 'TRIP'
        case '5': return 'TRIP'
        case other: return '!!!EXCEPTION!!!'

# %%
df['type'] = df.apply(add_type, axis=1)
df['cond'] = df.apply(add_trip, axis=1)

# %%
df = df.drop(['ack-all-value', 'use-ack-all', 'ack-tag', 'message-tag', 'message-handshake-exp', 'message-notification-tag', 'identifier', 'audio', 'display', 'print', 'message-to-tag', 'remote-ack-exp', 'remote-ack-handshake-tag', 'handshake-tag'], axis=1)

# %%
df
# Out:
#      id_x               type                        exp remote-ack-exp  \
# 0      T1           HighHigh    {[OPRA]TAG_WORD_AT601A}
# 1      T1               High    {[OPRA]TAG_WORD_AT601A}
# 2      T1      Sensor Defect    {[OPRA]TAG_WORD_AT601A}
# 3      T2      Sensor Defect    {[OPRA]TAG_WORD_FSL603}
# 4      T2  High Switch Alarm    {[OPRA]TAG_WORD_FSL603}
# ..    ...                ...                        ...            ...
# 536  T267  High Switch Alarm  {[OPRA]TAG_WORD_STEP_363}
# 537  T268  High Switch Alarm  {[OPRA]TAG_WORD_STEP_364}
# 538  T269  High Switch Alarm  {[OPRA]TAG_WORD_STEP_365}
# 539  T270      Sensor Defect     {[OPRA]TAG_WORD_XV375}
# 540  T271      Sensor Defect     {[OPRA]TAG_WORD_XV376}
#
#     remote-ack-handshake-tag    label handshake-tag  id_y trigger-value  \
# 0                              AT601A                  M7             1
# 1                              AT601A                  M8             2
# 2                              AT601A                  M9             5
# 3                              FSL603                 M93             5
# 4                              FSL603                 M94             6
# ..                       ...      ...           ...   ...           ...
# 536                           Step363                M538             6
# 537                           Step364                M539             6
# 538                           Step365                M540             6
# 539                             XV375                M534             5
# 540                             XV376                M535             5
#
#     trigger backcolor forecolor  \
# 0        T1   #FF0000   #000000
# 1        T1   #FFFF00   #000000
# 2        T1   #FF0000   #000000
# 3        T2   #FF0000   #000000
# 4        T2   #FF0000   #000000
# ..      ...       ...       ...
# 536    T267   #FF0000   #000000
# 537    T268   #FF0000   #000000
# 538    T269   #FF0000   #000000
# 539    T270   #FFFF00   #000000
# 540    T271   #FFFF00   #000000
#
#                                                   text        TRP/ALM
# 0    AT601A Gas Detection Engine Room Ventilation E...           TRIP
# 1    AT601A Gas Detection Engine Room Ventilation E...            ALM
# 2    AT601A Gas Detection Engine Room Ventilation E...  Sensor Defect
# 3    FSL603 Engine Room Overpressure Low Switch Sen...  Sensor Defect
# 4     FSL603 Engine Room Overpressure Low Switch Alarm            ALM
# ..                                                 ...            ...
# 536  Gas Fuel System Step 363 Timed Out (Gas Flush-...            ALM
# 537  Gas Fuel System Step 364 Timed Out (Stop Gas f...            ALM
# 538  Gas Fuel System Step 365 Timed Out (Close Gas ...            ALM
# 539   XV375 Liquid Fuel Main Block Valve Output Defect  Sensor Defect
# 540        XV376 Liquid Fuel Purge Valve Output Defect  Sensor Defect
#
# [541 rows x 14 columns]

# %%
len(df.columns), len(df_trg.columns), len(df_msg.columns)
# Out:
# (24, 13, 11)

# %%
# df.to_excel('combined_original.xlsx')
# df.to_csv('combined_original.csv')

# %%
with open("Voyageur_Unit1_Alarms.xml", 'rt') as f:
    xml_orig = f.read()

# %%
my_dict = xmltodict.parse(xml_orig)

# %%
alm_list_new = my_dict['AlarmCollection']['Alarm']

df_alm_new = pd.DataFrame(alm_list_new)

# %%
col_list = df_alm_new.columns.to_list()
new_col_list = [s.replace('@', '') for s in col_list]
df_alm_new.columns = new_col_list

# %%
df_alm_new.to_excel('new_alarms.xlsx')

# %%
df_alm_new.iloc[:,18:]
# Out:
#   AckRequired AlarmSetRollupIncluded AlarmSetOperIncluded Lang    Use  \
# 0        True                   True                 True       False
# 1        True                   True                 True       False
# 2        True                   True                 True        True
# 3        True                   True                 True        True
# 4        True                   True                 True        True
# 5        True                   True                 True        True
# 6        True                   True                 True        True
#
#   AlarmDefinition                                            Message  \
# 0                                            Gas_Detector_Diagnostic
# 1                                            Gas_Detector_Diagnostic
# 2                  TE810 Generator Front Bearing Temperature High...
# 3                  TE810 Generator Front Bearing Temperature High...
# 4                  TE811 Generator Rear Bearing Temperature High ...
# 5                  TE811 Generator Rear Bearing Temperature High ...
# 6                  TE811 Generator Rear Bearing Temperature High ...
#
#   AlarmClass HMIGroup HMICmd
# 0       None     None   None
# 1       None     None   None
# 2       None     None   None
# 3       None     None   None
# 4       None     None   None
# 5       None     None   None
# 6       None     None   None

# %%
# Out:
# '= 1'

# %%
def new_exp(row):
    s = row['exp']
    tr = str(int(row['trigger-value'])-1)
    s = s[s.find(']')+1:-1] + '_' + tr
    return s

# %%
df['new_exp'] = df.apply(new_exp, axis=1)

# %%
name = ['Trubine'] * len(df)
condition_type = df.type
input_f = df.new_exp
expression = ['=1'] * len(df)
limit = [0] * len(df)
target_tag = [''] * len(df)
on_delay = [0] * len(df)
off_delay = [0] * len(df)
deadband = [0] * len(df)
severity = [500] * len(df)
AssocTag1 = [''] * len(df)
AssocTag2 = [''] * len(df)
AssocTag3 = [''] * len(df)
AssocTag4 = [''] * len(df)
ShelveDuration = [0] * len(df)
MaxShelveDuration =	[0] * len(df)
EvaluationPeriod = [500] * len(df)
Latched	= [False] * len(df)
AckRequired = [True]  * len(df)
AlarmSetRollupIncluded = [True]  * len(df)
AlarmSetOperIncluded = [True]  * len(df)
Lang = [''] * len(df)
Use	= [True]  * len(df)
AlarmDefinition = [''] * len(df)
Message = df.text
AlarmClass = [None] * len(df)
HMIGroup = [None] * len(df)
HMICmd = [None] * len(df)

# %%
new_alarms_full = pd.DataFrame({'Name': name, 'ConditionType': condition_type, 'Input': input_f, 'Expression': expression, 'Limit': limit, 'TargetTag': target_tag,
                                'OnDelay': on_delay, 'OffDelay': off_delay, 'Deadband': deadband, 'Severity': severity, 'AssocTag1': AssocTag1, 'AssocTag2': AssocTag2, 
                                'AssocTag3': AssocTag3, 'AssocTag4': AssocTag4, 'ShelveDuration': ShelveDuration, 'MaxShelveDuration': MaxShelveDuration,
                                'EvaluationPeriod': EvaluationPeriod, 'Latched': Latched, 'AckRequired': AckRequired, 'AlarmSetRollupIncluded': AlarmSetRollupIncluded,
                                'AlarmSetOperIncluded': AlarmSetOperIncluded, 'Lang': Lang, 'Use': Use, 'AlarmDefinition': AlarmDefinition, 'Message': Message,
                                'AlarmClass': AlarmClass, 'HMIGroup': HMIGroup, 'HMICmd': HMICmd})

# %%
new_alarms_full
# Out:
#         Name      ConditionType                Input Expression  Limit  \
# 0    Trubine           HighHigh    TAG_WORD_AT601A_0         =1      0
# 1    Trubine               High    TAG_WORD_AT601A_1         =1      0
# 2    Trubine      Sensor Defect    TAG_WORD_AT601A_4         =1      0
# 3    Trubine      Sensor Defect    TAG_WORD_FSL603_4         =1      0
# 4    Trubine  High Switch Alarm    TAG_WORD_FSL603_5         =1      0
# ..       ...                ...                  ...        ...    ...
# 536  Trubine  High Switch Alarm  TAG_WORD_STEP_363_5         =1      0
# 537  Trubine  High Switch Alarm  TAG_WORD_STEP_364_5         =1      0
# 538  Trubine  High Switch Alarm  TAG_WORD_STEP_365_5         =1      0
# 539  Trubine      Sensor Defect     TAG_WORD_XV375_4         =1      0
# 540  Trubine      Sensor Defect     TAG_WORD_XV376_4         =1      0
#
#     TargetTag  OnDelay  OffDelay  Deadband  Severity  ... AckRequired  \
# 0                    0         0         0       500  ...        True
# 1                    0         0         0       500  ...        True
# 2                    0         0         0       500  ...        True
# 3                    0         0         0       500  ...        True
# 4                    0         0         0       500  ...        True
# ..        ...      ...       ...       ...       ...  ...         ...
# 536                  0         0         0       500  ...        True
# 537                  0         0         0       500  ...        True
# 538                  0         0         0       500  ...        True
# 539                  0         0         0       500  ...        True
# 540                  0         0         0       500  ...        True
#
#     AlarmSetRollupIncluded AlarmSetOperIncluded Lang   Use  AlarmDefinition  \
# 0                     True                 True       True
# 1                     True                 True       True
# 2                     True                 True       True
# 3                     True                 True       True
# 4                     True                 True       True
# ..                     ...                  ...  ...   ...              ...
# 536                   True                 True       True
# 537                   True                 True       True
# 538                   True                 True       True
# 539                   True                 True       True
# 540                   True                 True       True
#
#                                                Message  AlarmClass  HMIGroup  \
# 0    AT601A Gas Detection Engine Room Ventilation E...        None      None
# 1    AT601A Gas Detection Engine Room Ventilation E...        None      None
# 2    AT601A Gas Detection Engine Room Ventilation E...        None      None
# 3    FSL603 Engine Room Overpressure Low Switch Sen...        None      None
# 4     FSL603 Engine Room Overpressure Low Switch Alarm        None      None
# ..                                                 ...         ...       ...
# 536  Gas Fuel System Step 363 Timed Out (Gas Flush-...        None      None
# 537  Gas Fuel System Step 364 Timed Out (Stop Gas f...        None      None
# 538  Gas Fuel System Step 365 Timed Out (Close Gas ...        None      None
# 539   XV375 Liquid Fuel Main Block Valve Output Defect        None      None
# 540        XV376 Liquid Fuel Purge Valve Output Defect        None      None
#
#      HMICmd
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ..      ...
# 536    None
# 537    None
# 538    None
# 539    None
# 540    None
#
# [541 rows x 28 columns]

# %%
df
# Out:
#      id_x               type                        exp remote-ack-exp  \
# 0      T1           HighHigh    {[OPRA]TAG_WORD_AT601A}
# 1      T1               High    {[OPRA]TAG_WORD_AT601A}
# 2      T1      Sensor Defect    {[OPRA]TAG_WORD_AT601A}
# 3      T2      Sensor Defect    {[OPRA]TAG_WORD_FSL603}
# 4      T2  High Switch Alarm    {[OPRA]TAG_WORD_FSL603}
# ..    ...                ...                        ...            ...
# 536  T267  High Switch Alarm  {[OPRA]TAG_WORD_STEP_363}
# 537  T268  High Switch Alarm  {[OPRA]TAG_WORD_STEP_364}
# 538  T269  High Switch Alarm  {[OPRA]TAG_WORD_STEP_365}
# 539  T270      Sensor Defect     {[OPRA]TAG_WORD_XV375}
# 540  T271      Sensor Defect     {[OPRA]TAG_WORD_XV376}
#
#     remote-ack-handshake-tag    label handshake-tag  id_y trigger-value  \
# 0                              AT601A                  M7             1
# 1                              AT601A                  M8             2
# 2                              AT601A                  M9             5
# 3                              FSL603                 M93             5
# 4                              FSL603                 M94             6
# ..                       ...      ...           ...   ...           ...
# 536                           Step363                M538             6
# 537                           Step364                M539             6
# 538                           Step365                M540             6
# 539                             XV375                M534             5
# 540                             XV376                M535             5
#
#     trigger backcolor forecolor  \
# 0        T1   #FF0000   #000000
# 1        T1   #FFFF00   #000000
# 2        T1   #FF0000   #000000
# 3        T2   #FF0000   #000000
# 4        T2   #FF0000   #000000
# ..      ...       ...       ...
# 536    T267   #FF0000   #000000
# 537    T268   #FF0000   #000000
# 538    T269   #FF0000   #000000
# 539    T270   #FFFF00   #000000
# 540    T271   #FFFF00   #000000
#
#                                                   text        TRP/ALM  \
# 0    AT601A Gas Detection Engine Room Ventilation E...           TRIP
# 1    AT601A Gas Detection Engine Room Ventilation E...            ALM
# 2    AT601A Gas Detection Engine Room Ventilation E...  Sensor Defect
# 3    FSL603 Engine Room Overpressure Low Switch Sen...  Sensor Defect
# 4     FSL603 Engine Room Overpressure Low Switch Alarm            ALM
# ..                                                 ...            ...
# 536  Gas Fuel System Step 363 Timed Out (Gas Flush-...            ALM
# 537  Gas Fuel System Step 364 Timed Out (Stop Gas f...            ALM
# 538  Gas Fuel System Step 365 Timed Out (Close Gas ...            ALM
# 539   XV375 Liquid Fuel Main Block Valve Output Defect  Sensor Defect
# 540        XV376 Liquid Fuel Purge Valve Output Defect  Sensor Defect
#
#                  new_exp
# 0      TAG_WORD_AT601A_0
# 1      TAG_WORD_AT601A_1
# 2      TAG_WORD_AT601A_4
# 3      TAG_WORD_FSL603_4
# 4      TAG_WORD_FSL603_5
# ..                   ...
# 536  TAG_WORD_STEP_363_5
# 537  TAG_WORD_STEP_364_5
# 538  TAG_WORD_STEP_365_5
# 539     TAG_WORD_XV375_4
# 540     TAG_WORD_XV376_4
#
# [541 rows x 15 columns]

# %%
dict_list = new_alarms_full.to_dict('records')

# %%
my_dict['AlarmCollection'].keys()
# Out:
# dict_keys(['@xmlns:xsi', '@xmlns:xsd', 'Alarm'])

# %%
my_dict['AlarmCollection']

# %%
my_dict['AlarmCollection']['@xmlns:xsi']
# Out:
# 'http://www.w3.org/2001/XMLSchema-instance'

# %%
final_dict = {'AlarmCollection': {'xmlns:xsi': my_dict['AlarmCollection']['@xmlns:xsi'], 'xmlns:xsd': my_dict['AlarmCollection']['@xmlns:xsd'],
                                  'Alarm': dict_list}}

# %%
final_dict.keys(), my_dict.keys()
# Out:
# (dict_keys(['AlarmCollection']), dict_keys(['AlarmCollection']))

# %%
final_dict['AlarmCollection'].keys(), my_dict['AlarmCollection'].keys()
# Out:
# (dict_keys(['xmlns:xsi', 'xmlns:xsd', 'Alarm']),
#  dict_keys(['@xmlns:xsi', '@xmlns:xsd', 'Alarm']))

# %%
import collections
collections.Iterable = collections.abc.Iterable

# %%
from  dicttoxml import dicttoxml
from xml.dom.minidom import parseString

xml = dicttoxml(final_dict, attr_type = False)

with open('new_alarms_generated.xml', 'wt') as f:
    f.write(parseString(xml).toprettyxml())

# %%
xml
# Out:
# b'<?xml version="1.0" encoding="UTF-8" ?><root><AlarmCollection><key name="xmlns:xsi">http://www.w3.org/2001/XMLSchema-instance</key><key name="xmlns:xsd">http://www.w3.org/2001/XMLSchema</key><Alarm><item><Name>Trubine</Name><ConditionType>HighHigh</ConditionType><Input>TAG_WORD_AT601A_0</Input><Expression>=1</Expression><Limit>0</Limit><TargetTag></TargetTag><OnDelay>0</OnDelay><OffDelay>0</OffDelay><Deadband>0</Deadband><Severity>500</Severity><AssocTag1></AssocTag1><AssocTag2></AssocTag2><AssocTag3></AssocTag3><AssocTag4></AssocTag4><ShelveDuration>0</ShelveDuration><MaxShelveDuration>0</MaxShelveDuration><EvaluationPeriod>500</EvaluationPeriod><Latched>False</Latched><AckRequired>True</AckRequired><AlarmSetRollupIncluded>True</AlarmSetRollupIncluded><AlarmSetOperIncluded>True</AlarmSetOperIncluded><Lang></Lang><Use>True</Use><AlarmDefinition></AlarmDefinition><Message>AT601A Gas Detection Engine Room Ventilation Exit High Trip</Message><AlarmClass></AlarmClass><HMIGroup></HMIGroup><HMICmd></HMICmd></item><item><Name>Trubine</Name><ConditionType>High</ConditionType><Input>TAG_WORD_AT601A_1</Input><Expression>=1</Expression><Limit>0</Limit><TargetTag></TargetTag><OnDelay>0</OnDelay><OffDelay>0</OffDelay><Deadband>0</Deadband><Severity>500</Severity><AssocTag1></AssocTag1><AssocTag2></AssocTag2><AssocTag3></AssocTag3><AssocTag4></AssocTag4><ShelveDuration>0</ShelveDuration><MaxShelveDuration>0</MaxShelveDuration><EvaluationPeriod>500</EvaluationPeriod><Latched>False</Latched><AckRequired>True</AckRequired><AlarmSetRollupIncluded>True</AlarmSetRollupIncluded><AlarmSetOperIncluded>True</AlarmSetOperIncluded><Lang></Lang><Use>True</Use><AlarmDefinition></AlarmDefinition><Message>AT601A Gas Detection Engine Room Ventilation Exit High Alarm</Message><AlarmClass></AlarmClass><HMIGroup></HMIGroup><HMICmd></HMICmd></item><item><Name>Trubine</Name><ConditionType>Sensor Defect</ConditionType><Input>TAG_WORD_AT601A_4</Input><Expression>=1</Expression><Limit>0</Limit><TargetTag></TargetTag><OnDelay>0</OnDelay><OffDelay>0</OffDelay><Deadband>0</Deadband><Severity>500</Severity><AssocTag1></AssocTag1><AssocTag2></AssocTag2><AssocTag3></AssocTag3><AssocTag4></AssocTag4><ShelveDuration>0</ShelveDuration><MaxShelveDuration>0</MaxShelveDuration><EvaluationPeriod>500</EvaluationPeriod><Latched>False</Latched><AckRequired>True</AckRequired><AlarmSetRollupIncluded>True</AlarmSetRollupIncluded><AlarmSetOperIncluded>True</AlarmSetOperIncluded><Lang></Lang><Use>True</Use><AlarmDefinition></AlarmDefinition><Message>AT601A Gas Detection Engine Room Ventilation Exit Sensor Defect</Message><AlarmClass></AlarmClass><HMIGroup></HMIGroup><HMICmd></HMICmd></item><item><Name>Trubine</Name><ConditionType>Sensor Defect</ConditionType><Input>TAG_WORD_FSL603_4</Input><Expression>=1</Expression><Limit>0</Limit><TargetTag></TargetTag><OnDelay>0</OnDelay><OffDelay>0</OffDelay><Deadband>0</Deadband><Severity>500</Severity><AssocTag1></AssocTag1><AssocTag2></AssocTag2><AssocTag3></AssocTag3><AssocTag4></AssocTag4><ShelveDuration>0</ShelveDuration><MaxShelveDuration>0</MaxShelveDuration><EvaluationPeriod>500</EvaluationPeriod><Latched>False</Latched><AckRequired>True</AckRequired><AlarmSetRollupIncluded>True</AlarmSetRollupIncluded><AlarmSetOperIncluded>True</AlarmSetOperIncluded><Lang></Lang><Use>True</Use><AlarmDefinition></AlarmDefinition><Message>FSL603 Engine Room Overpressure Low Switch Sensor Defect</Message><AlarmClass></AlarmClass><HMIGroup></HMIGroup><HMICmd></HMICmd></item><item><Name>Trubine</Name><ConditionType>High Switch Alarm</ConditionType><Input>TAG_WORD_FSL603_5</Input><Expression>=1</Expression><Limit>0</Limit><TargetTag></TargetTag><OnDelay>0</OnDelay><OffDelay>0</OffDelay><Deadband>0</Deadband><Severity>500</Severity><AssocTag1></AssocTag1><AssocTag2></AssocTag2><AssocTag3></AssocTag3><AssocTag4></AssocTag4><ShelveDuration>0</ShelveDuration><MaxShelveDuration>0</MaxShelveDuration><EvaluationPeriod>500</EvaluationPeriod><Latched>False</Latched><A ...

# %%
final_dict
# Out:
# {'AlarmCollection': {'@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'xmlns:xsd': 'http://www.w3.org/2001/XMLSchema',
#   'Alarm': [{'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_AT601A_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'AT601A Gas Detection Engine Room Ventilation Exit High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_AT601A_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'AT601A Gas Detection Engine Room Ventilation Exit High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_AT601A_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'AT601A Gas Detection Engine Room Ventilation Exit Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_FSL603_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'FSL603 Engine Room Overpressure Low Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_FSL603_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'FSL603 Engine Room Overpressure Low Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_HS602_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'HS602 ESD Button Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_HS602_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'HS602 ESD Button',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_LSL335A_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'LSL335A Lube Oil Tank Level Low Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_LSL335A_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'LSL335A Lube Oil Tank Level Low Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_LSL335B_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'LSL335B Lube Oil Tank Level Low Low Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_LSL335B_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'LSL335B Lube Oil Tank Level Low Low Switch Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PDSH338_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH338 Lube Oil Suction Filter Pressure High Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_PDSH338_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH338 Lube Oil Suction Filter Pressure High Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PDSH332_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH332 Lube Oil Pressure Filter Pressure High Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_PDSH332_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH332 Lube Oil Pressure Filter Pressure High Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PDSH367_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH367 Gas Fuel Inlet Filter Differential Pressure High Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_PDSH367_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH367 Gas Fuel Inlet Filter Differential Pressure High Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PDSH388_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH388 Hydraulic Starter Oil Suction Filter Pressure Drop High Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_PDSH388_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PDSH388 Hydraulic Starter Oil Suction Filter Pressure Drop High Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PdT614_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT614 Enclosure Ventilation Air Filter Differential Pressure High Switch Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_PdT614_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT614 Enclosure Ventilation Air Filter Differential Pressure High Switch Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PdT606_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT606 Engine Inlet Prefilter Differential Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PdT606_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT606 Engine Inlet Prefilter Differential Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PdT606_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT606 Engine Inlet Prefilter Differential Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PdT607_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT607 Engine Inlet Fine Filter Differential Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PdT607_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT607 Engine Inlet Fine Filter Differential Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PdT607_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdT607 Engine Inlet Fine Filter Differential Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PdY364_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdY364 Gas Fuel Supply Differential Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PdY364_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PdY364 Gas Fuel Supply Differential Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT110_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT110 Engine Inlet Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT110_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT110 Engine Inlet Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT110_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT110 Engine Inlet Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT110_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT110 Engine Inlet Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT110_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT110 Engine Inlet Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT160_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT160 Exhaust Gas Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT160_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT160 Exhaust Gas Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT160_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT160 Exhaust Gas Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT160_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT160 Exhaust Gas Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT160_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT160 Exhaust Gas Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT231_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT231 Lube Oil Inlet Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT231_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT231 Lube Oil Inlet Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT231_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT231 Lube Oil Inlet Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT231_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT231 Lube Oil Inlet Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT231_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT231 Lube Oil Inlet Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT240_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT240 Seal Air Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT240_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT240 Seal Air Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT240_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT240 Seal Air Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT240_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT240 Seal Air Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT240_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT240 Seal Air Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT341_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT341 Air Supply Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT341_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT341 Air Supply Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT341_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT341 Air Supply Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT341_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT341 Air Supply Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT341_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT341 Air Supply Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT360_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT360 Gas Fuel Nozzle Pressure High trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT360_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT360 Gas Fuel Nozzle Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT360_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT360 Gas Fuel Nozzle Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT360_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT360 Gas Fuel Nozzle Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT360_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT360 Gas Fuel Nozzle Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT364A_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364A Gas Fuel Supply Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT364A_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364A Gas Fuel Supply Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT364A_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364A Gas Fuel Supply Pressure Low Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT364A_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364A Gas Fuel Supply Pressure Low Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_PT364A_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364A Gas Fuel Supply Pressure Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'HighHigh',
#     'Input': 'TAG_WORD_PT364B_0',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364B Gas Fuel Supply Pressure High Trip',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High',
#     'Input': 'TAG_WORD_PT364B_1',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364B Gas Fuel Supply Pressure High Alarm',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Low',
#     'Input': 'TAG_WORD_PT364B_2',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'PT364B Gas Fuel Supply Pressure Low Alarm, ',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'LowLow',
#     'Input': 'TAG_WORD_PT364B_3',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
# ...
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS361 Gas Fuel Valve Not Healthy',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS336D_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS336D Lube Oil Tank thermostat Sensor Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS995_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS995 Download Bypass Switch input Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YS995_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS995 Download Bypass Switch Active',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS627_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS627 Gas Detected In Engine Room Sensor Fault',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YS627_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS627 Gas Detected In Engine Room',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS628_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS628 Gas Detected At Engine Ventilation Inlet Sensor Fault',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YS628_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS628 Gas Detected At Engine Ventilation Inlet',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS629_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS629 Gas Detected At Control Room Sensor Fault',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YS629_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS629 Gas Detected At Control Room',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS520_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS520 ESD 2 Low, Change to Liquid Fuel Sensor Fault',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YS520_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS520 ESD 2 Low, Change to Liquid Fuel ',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_YS522_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS522 ESD 0 APS Sensor Fault',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YS522_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YS522 ESD 0 APS',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_WHRU_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'WHRU Purging Failure',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_YX630_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'YX630 Standstill Heater For Redundant Enclosure Fan Thermal Fault',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_STEP_361_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'Gas Fuel System Step 362 Timed Out (Start Gas Flush-Open Gas Fuel Shut-Off Valve)',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_STEP_362_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'Gas Fuel System Step 362 Timed Out (Gas Flush-Open Gas Fuel Blow-off Valve)',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_STEP_363_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'Gas Fuel System Step 363 Timed Out (Gas Flush-Until Temperature is above Minimum)',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_STEP_364_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'Gas Fuel System Step 364 Timed Out (Stop Gas flush- Close Gas Fuel Blow-off Valve)',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'High Switch Alarm',
#     'Input': 'TAG_WORD_STEP_365_5',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'Gas Fuel System Step 365 Timed Out (Close Gas Fuel Shut-Off Valve)',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_XV375_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'XV375 Liquid Fuel Main Block Valve Output Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None},
#    {'Name': 'Trubine',
#     'ConditionType': 'Sensor Defect',
#     'Input': 'TAG_WORD_XV376_4',
#     'Expression': '=1',
#     'Limit': 0,
#     'TargetTag': '',
#     'OnDelay': 0,
#     'OffDelay': 0,
#     'Deadband': 0,
#     'Severity': 500,
#     'AssocTag1': '',
#     'AssocTag2': '',
#     'AssocTag3': '',
#     'AssocTag4': '',
#     'ShelveDuration': 0,
#     'MaxShelveDuration': 0,
#     'EvaluationPeriod': 500,
#     'Latched': False,
#     'AckRequired': True,
#     'AlarmSetRollupIncluded': True,
#     'AlarmSetOperIncluded': True,
#     'Lang': '',
#     'Use': True,
#     'AlarmDefinition': '',
#     'Message': 'XV376 Liquid Fuel Purge Valve Output Defect',
#     'AlarmClass': None,
#     'HMIGroup': None,
#     'HMICmd': None}]}}

# %%
dict_list
# Out:
# [{'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_AT601A_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'AT601A Gas Detection Engine Room Ventilation Exit High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_AT601A_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'AT601A Gas Detection Engine Room Ventilation Exit High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_AT601A_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'AT601A Gas Detection Engine Room Ventilation Exit Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_FSL603_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'FSL603 Engine Room Overpressure Low Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_FSL603_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'FSL603 Engine Room Overpressure Low Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_HS602_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'HS602 ESD Button Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_HS602_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'HS602 ESD Button',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_LSL335A_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'LSL335A Lube Oil Tank Level Low Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_LSL335A_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'LSL335A Lube Oil Tank Level Low Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_LSL335B_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'LSL335B Lube Oil Tank Level Low Low Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_LSL335B_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'LSL335B Lube Oil Tank Level Low Low Switch Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PDSH338_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH338 Lube Oil Suction Filter Pressure High Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_PDSH338_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH338 Lube Oil Suction Filter Pressure High Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PDSH332_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH332 Lube Oil Pressure Filter Pressure High Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_PDSH332_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH332 Lube Oil Pressure Filter Pressure High Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PDSH367_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH367 Gas Fuel Inlet Filter Differential Pressure High Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_PDSH367_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH367 Gas Fuel Inlet Filter Differential Pressure High Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PDSH388_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH388 Hydraulic Starter Oil Suction Filter Pressure Drop High Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_PDSH388_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PDSH388 Hydraulic Starter Oil Suction Filter Pressure Drop High Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PdT614_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT614 Enclosure Ventilation Air Filter Differential Pressure High Switch Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_PdT614_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT614 Enclosure Ventilation Air Filter Differential Pressure High Switch Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PdT606_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT606 Engine Inlet Prefilter Differential Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PdT606_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT606 Engine Inlet Prefilter Differential Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PdT606_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT606 Engine Inlet Prefilter Differential Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PdT607_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT607 Engine Inlet Fine Filter Differential Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PdT607_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT607 Engine Inlet Fine Filter Differential Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PdT607_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdT607 Engine Inlet Fine Filter Differential Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PdY364_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdY364 Gas Fuel Supply Differential Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PdY364_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PdY364 Gas Fuel Supply Differential Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT110_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT110 Engine Inlet Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT110_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT110 Engine Inlet Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT110_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT110 Engine Inlet Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT110_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT110 Engine Inlet Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT110_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT110 Engine Inlet Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT160_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT160 Exhaust Gas Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT160_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT160 Exhaust Gas Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT160_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT160 Exhaust Gas Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT160_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT160 Exhaust Gas Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT160_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT160 Exhaust Gas Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT231_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT231 Lube Oil Inlet Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT231_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT231 Lube Oil Inlet Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT231_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT231 Lube Oil Inlet Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT231_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT231 Lube Oil Inlet Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT231_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT231 Lube Oil Inlet Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT240_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT240 Seal Air Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT240_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT240 Seal Air Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT240_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT240 Seal Air Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT240_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT240 Seal Air Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT240_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT240 Seal Air Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT341_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT341 Air Supply Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT341_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT341 Air Supply Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT341_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT341 Air Supply Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT341_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT341 Air Supply Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT341_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT341 Air Supply Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT360_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT360 Gas Fuel Nozzle Pressure High trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT360_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT360 Gas Fuel Nozzle Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT360_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT360 Gas Fuel Nozzle Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT360_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT360 Gas Fuel Nozzle Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT360_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT360 Gas Fuel Nozzle Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT364A_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364A Gas Fuel Supply Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT364A_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364A Gas Fuel Supply Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT364A_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364A Gas Fuel Supply Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT364A_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364A Gas Fuel Supply Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT364A_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364A Gas Fuel Supply Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT364B_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364B Gas Fuel Supply Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT364B_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364B Gas Fuel Supply Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT364B_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364B Gas Fuel Supply Pressure Low Alarm, ',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT364B_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364B Gas Fuel Supply Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT364B_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT364B Gas Fuel Supply Pressure Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'HighHigh',
#   'Input': 'TAG_WORD_PT375_0',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT375 Liquid Fuel Nozzle Pressure High Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High',
#   'Input': 'TAG_WORD_PT375_1',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT375 Liquid Fuel Nozzle Pressure High Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Low',
#   'Input': 'TAG_WORD_PT375_2',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT375 Liquid Fuel Nozzle Pressure Low Alarm',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'LowLow',
#   'Input': 'TAG_WORD_PT375_3',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT375 Liquid Fuel Nozzle Pressure Low Trip',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_PT375_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'PT375 Liquid Fuel Nozzle Pressure Sensor Defect',
#   'AlarmClass': None,
# ...
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Compact Flash Card No Datafile',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'EXCEPTION',
#   'Input': 'TAG_WORD_CF_7',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Card Error, contact Opra',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS361_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS361 Gas Fuel Valve Not Healthy',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS336D_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS336D Lube Oil Tank thermostat Sensor Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS995_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS995 Download Bypass Switch input Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS995_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS995 Download Bypass Switch Active',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS627_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS627 Gas Detected In Engine Room Sensor Fault',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS627_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS627 Gas Detected In Engine Room',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS628_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS628 Gas Detected At Engine Ventilation Inlet Sensor Fault',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS628_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS628 Gas Detected At Engine Ventilation Inlet',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS629_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS629 Gas Detected At Control Room Sensor Fault',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS629_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS629 Gas Detected At Control Room',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS520_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS520 ESD 2 Low, Change to Liquid Fuel Sensor Fault',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS520_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS520 ESD 2 Low, Change to Liquid Fuel ',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_YS522_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS522 ESD 0 APS Sensor Fault',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YS522_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YS522 ESD 0 APS',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_WHRU_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'WHRU Purging Failure',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_YX630_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'YX630 Standstill Heater For Redundant Enclosure Fan Thermal Fault',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_STEP_361_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Gas Fuel System Step 362 Timed Out (Start Gas Flush-Open Gas Fuel Shut-Off Valve)',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_STEP_362_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Gas Fuel System Step 362 Timed Out (Gas Flush-Open Gas Fuel Blow-off Valve)',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_STEP_363_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Gas Fuel System Step 363 Timed Out (Gas Flush-Until Temperature is above Minimum)',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_STEP_364_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Gas Fuel System Step 364 Timed Out (Stop Gas flush- Close Gas Fuel Blow-off Valve)',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'High Switch Alarm',
#   'Input': 'TAG_WORD_STEP_365_5',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'Gas Fuel System Step 365 Timed Out (Close Gas Fuel Shut-Off Valve)',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_XV375_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'XV375 Liquid Fuel Main Block Valve Output Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None},
#  {'Name': 'Trubine',
#   'ConditionType': 'Sensor Defect',
#   'Input': 'TAG_WORD_XV376_4',
#   'Expression': '=1',
#   'Limit': 0,
#   'TargetTag': '',
#   'OnDelay': 0,
#   'OffDelay': 0,
#   'Deadband': 0,
#   'Severity': 500,
#   'AssocTag1': '',
#   'AssocTag2': '',
#   'AssocTag3': '',
#   'AssocTag4': '',
#   'ShelveDuration': 0,
#   'MaxShelveDuration': 0,
#   'EvaluationPeriod': 500,
#   'Latched': False,
#   'AckRequired': True,
#   'AlarmSetRollupIncluded': True,
#   'AlarmSetOperIncluded': True,
#   'Lang': '',
#   'Use': True,
#   'AlarmDefinition': '',
#   'Message': 'XV376 Liquid Fuel Purge Valve Output Defect',
#   'AlarmClass': None,
#   'HMIGroup': None,
#   'HMICmd': None}]

# %%
# Make xml as text

s = '<?xml version="1.0" encoding="utf-8"?>\n'
s += '<AlarmCollection xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema">\n'

# %%
def get_alarm_from_dict(row):
    #print(row.Name)
    s = f'\t<Alarm Name="{row.Name}" ConditionType="{row.ConditionType}" Input="{row.Input}" Expression"=1" Limit="0" TargetTag="" OnDelay="0" OffDelay="0" Deadband="0" Severity="500" AssocTag1="" AssocTag2="" AssocTag3="" AssocTag4="" ShelveDuration="0" MaxShelveDuration="0" EvaluationPeriod="500" Latched="False" AckRequired="True" AlarmSetRollupIncluded="True" AlarmSetOperIncluded="True" Lang="" Use="True" AlarmDefinition="">\n'
    s += f'\t\t<Message><![CDATA[{row.Message}]]></Message>\n\t\t<AlarmClass><![CDATA[]]></AlarmClass>\n\t\t<HMIGroup><![CDATA[]]></HMIGroup>\n\t\t<HMICmd><![CDATA[]]></HMICmd>\n\t</Alarm>\n'
    return s

# %%
s1 = list(new_alarms_full.apply(get_alarm_from_dict, axis=1))

# %%
s1.insert(0, s)
s1.append('</AlarmCollection>')

# %%
with open('new_alarms_generated.xml', 'wt') as f:
    f.writelines( s1)
